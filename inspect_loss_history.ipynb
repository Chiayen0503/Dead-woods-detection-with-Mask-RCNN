# %% [markdown]
# # Visualize loss function - All losses

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("score.csv")
history = pd.concat(frames)
epochs = range(1,len(df)+1)
plt.figure(figsize=(15,5))

plt.subplot(231)
plt.plot(epochs, history["mrcnn_class_loss"], label="Train class loss")
plt.plot(epochs, history["val_mrcnn_class_loss"], label="Valid class loss")
plt.legend()
plt.title("Mrcnn classification loss")

plt.subplot(232)
plt.plot(epochs, history["mrcnn_bbox_loss"], label="Train box loss")
plt.plot(epochs, history["val_mrcnn_bbox_loss"], label="Valid box loss")
plt.legend()
plt.title("Mrcnn Bounding Box Loss")

plt.subplot(233)
plt.plot(epochs, history["mrcnn_mask_loss"], label="Train mask loss")
plt.plot(epochs, history["val_mrcnn_mask_loss"], label="Valid mask loss")
plt.legend()
plt.title("Mrcnn Mask Loss")

plt.subplots_adjust(hspace = 0.5)
plt.subplot(234)
plt.plot(epochs, history["rpn_class_loss"], label="Train rpn class loss")
plt.plot(epochs, history["val_rpn_class_loss"], label="Valid rpn class loss")
plt.legend()
plt.title("Region Proposal Network Classification Loss")

plt.subplot(235)
plt.plot(epochs, history["rpn_bbox_loss"], label="Train rpn box loss")
plt.plot(epochs, history["val_rpn_bbox_loss"], label="Valid rpn box loss")
plt.legend()
plt.title("Region Proposal Network Bounding Box Loss")

plt.subplot(236)
plt.plot(epochs, history["loss"], label="Train loss")
plt.plot(epochs, history["val_loss"], label="Valid loss")
plt.legend()
plt.title("Total Loss")

plt.show()

# %% [markdown]
# # Visualize loss function - Mrcnn

# %%
plt.figure(figsize=(17,5))
plt.subplot(131)
plt.plot(epochs, history["mrcnn_class_loss"], label="Train class loss")
plt.plot(epochs, history["val_mrcnn_class_loss"], label="Valid class loss")
plt.legend()
plt.title("Mrcnn classification loss")

plt.subplot(132)
plt.plot(epochs, history["mrcnn_bbox_loss"], label="Train box loss")
plt.plot(epochs, history["val_mrcnn_bbox_loss"], label="Valid box loss")
plt.legend()
plt.title("Mrcnn Bounding Box Loss")

plt.subplot(133)
plt.plot(epochs, history["mrcnn_mask_loss"], label="Train mask loss")
plt.plot(epochs, history["val_mrcnn_mask_loss"], label="Valid mask loss")
plt.legend()
plt.title("Mrcnn Mask Loss")

plt.show()

# %% [markdown]
# # Visualize loss function - RPN

# %%
plt.figure(figsize=(11,5))
plt.subplot(121)
plt.plot(epochs, history["rpn_class_loss"], label="Train rpn class loss")
plt.plot(epochs, history["val_rpn_class_loss"], label="Valid rpn class loss")
plt.legend()
plt.title("Region Proposal Network Classification Loss")
plt.subplot(122)
plt.plot(epochs, history["rpn_bbox_loss"], label="Train rpn box loss")
plt.plot(epochs, history["val_rpn_bbox_loss"], label="Valid rpn box loss")
plt.legend()
plt.title("Region Proposal Network Bounding Box Loss")
plt.show()

# %% [markdown]
# # Visualize loss function - Total loss

# %%
plt.figure(figsize=(5,5))

plt.subplot(111)

plt.plot(epochs, history["loss"], label="Train loss")
plt.plot(epochs, history["val_loss"], label="Valid loss")
plt.legend()
plt.title("Total Loss")

plt.show()
